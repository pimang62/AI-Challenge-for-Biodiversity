# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os

files = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        files.append(filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/solar-beehive/2022-09.csv
# /kaggle/input/solar-beehive/2022-11.csv
# /kaggle/input/solar-beehive/2023-06.csv
# /kaggle/input/solar-beehive/2023-01.csv
# /kaggle/input/solar-beehive/2023-11.csv
# /kaggle/input/solar-beehive/2022-12.csv
# /kaggle/input/solar-beehive/2023-03.csv
# /kaggle/input/solar-beehive/2022-08.csv
# /kaggle/input/solar-beehive/2023-04.csv
# /kaggle/input/solar-beehive/2023-07.csv
# /kaggle/input/solar-beehive/2023-02.csv
# /kaggle/input/solar-beehive/2022-07.csv
# /kaggle/input/solar-beehive/2022-10.csv
# /kaggle/input/solar-beehive/2023-12.csv
# /kaggle/input/solar-beehive/2023-09.csv
# /kaggle/input/solar-beehive/2023-05.csv
# /kaggle/input/solar-beehive/2023-08.csv
# /kaggle/input/solar-beehive/2023-10.csv

# %%
dirname
# Out:
# '/kaggle/input/solar-beehive'

# %%
files
# Out:
# ['2022-09.csv',
#  '2022-11.csv',
#  '2023-06.csv',
#  '2023-01.csv',
#  '2023-11.csv',
#  '2022-12.csv',
#  '2023-03.csv',
#  '2022-08.csv',
#  '2023-04.csv',
#  '2023-07.csv',
#  '2023-02.csv',
#  '2022-07.csv',
#  '2022-10.csv',
#  '2023-12.csv',
#  '2023-09.csv',
#  '2023-05.csv',
#  '2023-08.csv',
#  '2023-10.csv']

# %%
# make df by date name
df_2022_07 = pd.read_csv(os.path.join(dirname, '2022-07.csv'))
df_2022_08 = pd.read_csv(os.path.join(dirname, '2022-08.csv'))
df_2022_09 = pd.read_csv(os.path.join(dirname, '2022-09.csv'))
df_2022_10 = pd.read_csv(os.path.join(dirname, '2022-10.csv'))
df_2022_11 = pd.read_csv(os.path.join(dirname, '2022-11.csv'))
df_2022_12 = pd.read_csv(os.path.join(dirname, '2022-12.csv'))
df_2023_01 = pd.read_csv(os.path.join(dirname, '2023-01.csv'))
df_2023_02 = pd.read_csv(os.path.join(dirname, '2023-02.csv'))
df_2023_03 = pd.read_csv(os.path.join(dirname, '2023-03.csv'))
df_2023_04 = pd.read_csv(os.path.join(dirname, '2023-04.csv'))
df_2023_05 = pd.read_csv(os.path.join(dirname, '2023-05.csv'))
df_2023_06 = pd.read_csv(os.path.join(dirname, '2023-06.csv'))

df_2022_07
# Out:
#      hiveid  recordday   temp  humidity     co2  weight  incount  outcount  \
# 0         1          1  35.39     82.62  805.58   25100    67373    139549
# 1         1          2  35.32     82.49  760.57   25550    72354    136499
# 2         1          3  35.32     82.74  850.46   24800    76658    136779
# 3         1          4  35.20     83.06  777.32   24850    70647    135589
# 4         1          5  35.18     84.23  899.56   25250    77334    141126
# ..      ...        ...    ...       ...     ...     ...      ...       ...
# 119       4         27  32.59     27.55  863.58   21200     1912     49074
# 120       4         28  34.98     47.00  446.35   19850     8293    146664
# 121       4         29  35.43     51.17  544.96   20750     1849    133450
# 122       4         30  35.47     70.41  540.66   20750     1343    116716
# 123       4         31  35.53     73.55  817.30   21000     2508     98998
#
#      pm10  pm25  extemphigh  extemplow
# 0      14     5        33.2       24.2
# 1      26    17        34.1       23.4
# 2      27    18        33.5       24.5
# 3      23    13        32.1       24.0
# 4      34    23        30.7       24.5
# ..    ...   ...         ...        ...
# 119    25    17        33.2       24.1
# 120    26    17        34.8       22.7
# 121    21    14        35.6       25.9
# 122    15     9        32.9       24.7
# 123    10     5        29.0       24.7
#
# [124 rows x 12 columns]

# %%
# split by hiveid == 1
df_2022_07 = df_2022_07[df_2022_07['hiveid'] == 1]
df_2022_08 = df_2022_08[df_2022_08['hiveid'] == 1]
df_2022_09 = df_2022_09[df_2022_09['hiveid'] == 1]
df_2022_10 = df_2022_10[df_2022_10['hiveid'] == 1]
df_2022_11 = df_2022_11[df_2022_11['hiveid'] == 1]
df_2022_12 = df_2022_12[df_2022_12['hiveid'] == 1]
df_2023_01 = df_2023_01[df_2023_01['hiveid'] == 1]
df_2023_02 = df_2023_02[df_2023_02['hiveid'] == 1]
df_2023_03 = df_2023_03[df_2023_03['hiveid'] == 1]
df_2023_04 = df_2023_04[df_2023_04['hiveid'] == 1]
df_2023_05 = df_2023_05[df_2023_05['hiveid'] == 1]
df_2023_06 = df_2023_06[df_2023_06['hiveid'] == 1]

df_2022_07.tail()
# Out:
#     hiveid  recordday   temp  humidity      co2  weight  incount  outcount  \
# 26       1         27  34.72     78.55   646.40   25900    20619     80857
# 27       1         28  34.54     78.09   715.64   25600    22007     73744
# 28       1         29  35.26     78.70   520.84   25650    15640     74974
# 29       1         30  34.87     77.47   552.45   25000    15727     65773
# 30       1         31  34.52     77.11  1000.68   23850    11850     43010
#
#     pm10  pm25  extemphigh  extemplow
# 26    25    17        33.2       24.1
# 27    26    17        34.8       22.7
# 28    21    14        35.6       25.9
# 29    15     9        32.9       24.7
# 30    10     5        29.0       24.7

# %%
# labeling last 2 column : ['temp', 'outcount'] 
def preprocessing(df):
    df_front = df[[c for c in df.columns if c not in ['temp', 'outcount']]]
    df_back = df[['temp', 'outcount']]
    df = pd.concat([df_front, df_back], axis=1)
    return df

df_2022_07 = preprocessing(df_2022_07)
df_2022_08 = preprocessing(df_2022_08)
df_2022_09 = preprocessing(df_2022_09)
df_2022_10 = preprocessing(df_2022_10)
df_2022_11 = preprocessing(df_2022_11)
df_2022_12 = preprocessing(df_2022_12)
df_2023_01 = preprocessing(df_2023_01)
df_2023_02 = preprocessing(df_2023_02)
df_2023_03 = preprocessing(df_2023_03)
df_2023_04 = preprocessing(df_2023_04)
df_2023_05 = preprocessing(df_2023_05)
df_2023_06 = preprocessing(df_2023_06)

df_2022_07.tail()
# Out:
#     hiveid  recordday  humidity      co2  weight  incount  pm10  pm25  \
# 26       1         27     78.55   646.40   25900    20619    25    17
# 27       1         28     78.09   715.64   25600    22007    26    17
# 28       1         29     78.70   520.84   25650    15640    21    14
# 29       1         30     77.47   552.45   25000    15727    15     9
# 30       1         31     77.11  1000.68   23850    11850    10     5
#
#     extemphigh  extemplow   temp  outcount
# 26        33.2       24.1  34.72     80857
# 27        34.8       22.7  34.54     73744
# 28        35.6       25.9  35.26     74974
# 29        32.9       24.7  34.87     65773
# 30        29.0       24.7  34.52     43010

# %%
df_spring = pd.concat([df_2023_03, df_2023_04], axis=0)
df_spring = df_spring.reset_index()  # 0~60

print(len(df_spring))  # 31+30
df_spring.tail()
# Out:
# 61
#     index  hiveid  recordday  humidity   co2  weight  incount  pm10  pm25  \
# 56     25       1         26     72.91  3531   11700    38152    31    21
# 57     26       1         27     74.49  3127   11650    10357    38    21
# 58     27       1         28     74.21  3079   11550    30027    37    18
# 59     28       1         29     69.83  1926   11650    30367    35    17
# 60     29       1         30     69.07  2904   11650    52735    46    17
#
#     extemphigh  extemplow   temp  outcount
# 56        13.5        6.2  33.45        13
# 57        22.3        3.3  31.46       140
# 58        23.4        7.7  34.18       954
# 59        18.7        9.6  34.12       358
# 60        20.9        7.5  34.16       185

# %%
df_spring.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       61 non-null     int64
#  1   hiveid      61 non-null     int64
#  2   recordday   61 non-null     int64
#  3   humidity    61 non-null     float64
#  4   co2         61 non-null     int64
#  5   weight      61 non-null     int64
#  6   incount     61 non-null     int64
#  7   pm10        61 non-null     int64
#  8   pm25        61 non-null     int64
#  9   extemphigh  61 non-null     float64
#  10  extemplow   61 non-null     float64
#  11  temp        61 non-null     float64
#  12  outcount    61 non-null     int64
# dtypes: float64(4), int64(9)
# memory usage: 6.3 KB

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
        plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %%
label_columns = ['temp', 'outcount']

# initialize list
time_steps = []
labels = []

for i, row in df_spring.iterrows():
    time_steps.append(int(i))
    labels.append([float(row[-2]), int(row[-1])])

time = np.array(time_steps)
series = np.array(labels)

plot_series(time, series, xlabel='Date', ylabel='Temperature-Outcount')
plot_series(time, series[:, 0], xlabel='Date', ylabel='Temperature')
plot_series(time, series[:, 1], xlabel='Date', ylabel='Outcount')

# %%
# Define the split time
split_time = 55

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    """Generates dataset windows

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the feature
      batch_size (int) - the batch size
      shuffle_buffer(int) - buffer size to use for the shuffle method

    Returns:
      dataset (TF Dataset) - TF Dataset containing time windows
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

    # Create tuples with features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))

    # Shuffle the windows
    dataset = dataset.shuffle(shuffle_buffer)

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    return dataset

# %%
# Parameters
window_size = 3
batch_size = 16
shuffle_buffer_size = 100

# Generate the dataset windows
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
train_set
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 2), dtype=tf.float64, name=None), TensorSpec(shape=(None, 2), dtype=tf.float64, name=None))>

# %%
# Build the Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                           strides=1,
                           activation="relu",
                           padding='causal',
                           input_shape=[window_size, 2]),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(2),
    tf.keras.layers.Lambda(lambda x: (x[0] * 1000), (x[0] * )
])

 # Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 3, 64)             448
#
#  lstm_2 (LSTM)               (None, 3, 64)             33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_3 (Dense)             (None, 30)                1950
#
#  dense_4 (Dense)             (None, 10)                310
#
#  dense_5 (Dense)             (None, 2)                 22
#
#  lambda_1 (Lambda)           (None, 2)                 0
#
# =================================================================
# Total params: 68778 (268.66 KB)
# Trainable params: 68778 (268.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Get initial weights
init_weights = model.get_weights()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])

# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 128.6447 - lr: 1.0000e-08
# Epoch 2/100
# 4/4 [==============================] - 0s 8ms/step - loss: 128.4108 - lr: 1.1220e-08
# Epoch 3/100
# 4/4 [==============================] - 0s 8ms/step - loss: 127.9801 - lr: 1.2589e-08
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 127.3853 - lr: 1.4125e-08
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 126.6593 - lr: 1.5849e-08
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 125.8573 - lr: 1.7783e-08
# Epoch 7/100
# 4/4 [==============================] - 0s 7ms/step - loss: 124.8989 - lr: 1.9953e-08
# Epoch 8/100
# 4/4 [==============================] - 0s 7ms/step - loss: 123.8481 - lr: 2.2387e-08
# Epoch 9/100
# 4/4 [==============================] - 0s 8ms/step - loss: 122.6014 - lr: 2.5119e-08
# Epoch 10/100
# 4/4 [==============================] - 0s 7ms/step - loss: 121.2163 - lr: 2.8184e-08
# Epoch 11/100
# 4/4 [==============================] - 0s 7ms/step - loss: 119.6786 - lr: 3.1623e-08
# Epoch 12/100
# 4/4 [==============================] - 0s 7ms/step - loss: 117.8860 - lr: 3.5481e-08
# Epoch 13/100
# 4/4 [==============================] - 0s 8ms/step - loss: 115.9615 - lr: 3.9811e-08
# Epoch 14/100
# 4/4 [==============================] - 0s 7ms/step - loss: 113.7786 - lr: 4.4668e-08
# Epoch 15/100
# 4/4 [==============================] - 0s 8ms/step - loss: 111.3056 - lr: 5.0119e-08
# Epoch 16/100
# 4/4 [==============================] - 0s 8ms/step - loss: 108.6027 - lr: 5.6234e-08
# Epoch 17/100
# 4/4 [==============================] - 0s 8ms/step - loss: 105.6510 - lr: 6.3096e-08
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: 102.4815 - lr: 7.0795e-08
# Epoch 19/100
# 4/4 [==============================] - 0s 7ms/step - loss: 98.9404 - lr: 7.9433e-08
# Epoch 20/100
# 4/4 [==============================] - 0s 9ms/step - loss: 95.1695 - lr: 8.9125e-08
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 90.9735 - lr: 1.0000e-07
# Epoch 22/100
# 4/4 [==============================] - 0s 9ms/step - loss: 86.5318 - lr: 1.1220e-07
# Epoch 23/100
# 4/4 [==============================] - 0s 8ms/step - loss: 81.7066 - lr: 1.2589e-07
# Epoch 24/100
# 4/4 [==============================] - 0s 8ms/step - loss: 76.8744 - lr: 1.4125e-07
# Epoch 25/100
# 4/4 [==============================] - 0s 7ms/step - loss: 72.4695 - lr: 1.5849e-07
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 68.4469 - lr: 1.7783e-07
# Epoch 27/100
# 4/4 [==============================] - 0s 8ms/step - loss: 64.9174 - lr: 1.9953e-07
# Epoch 28/100
# 4/4 [==============================] - 0s 8ms/step - loss: 62.4981 - lr: 2.2387e-07
# Epoch 29/100
# 4/4 [==============================] - 0s 7ms/step - loss: 60.3858 - lr: 2.5119e-07
# Epoch 30/100
# 4/4 [==============================] - 0s 8ms/step - loss: 59.3582 - lr: 2.8184e-07
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 58.6727 - lr: 3.1623e-07
# Epoch 32/100
# 4/4 [==============================] - 0s 8ms/step - loss: 57.4598 - lr: 3.5481e-07
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 56.5760 - lr: 3.9811e-07
# Epoch 34/100
# 4/4 [==============================] - 0s 8ms/step - loss: 54.8666 - lr: 4.4668e-07
# Epoch 35/100
# 4/4 [==============================] - 0s 7ms/step - loss: 54.2573 - lr: 5.0119e-07
# Epoch 36/100
# 4/4 [==============================] - 0s 7ms/step - loss: 52.8105 - lr: 5.6234e-07
# Epoch 37/100
# 4/4 [==============================] - 0s 8ms/step - loss: 51.5648 - lr: 6.3096e-07
# Epoch 38/100
# 4/4 [==============================] - 0s 7ms/step - loss: 50.3088 - lr: 7.0795e-07
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 49.5148 - lr: 7.9433e-07
# Epoch 40/100
# 4/4 [==============================] - 0s 8ms/step - loss: 49.1685 - lr: 8.9125e-07
# Epoch 41/100
# 4/4 [==============================] - 0s 7ms/step - loss: 48.3496 - lr: 1.0000e-06
# Epoch 42/100
# 4/4 [==============================] - 0s 7ms/step - loss: 46.4130 - lr: 1.1220e-06
# Epoch 43/100
# 4/4 [==============================] - 0s 9ms/step - loss: 46.2876 - lr: 1.2589e-06
# Epoch 44/100
# 4/4 [==============================] - 0s 8ms/step - loss: 44.0844 - lr: 1.4125e-06
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 42.6413 - lr: 1.5849e-06
# Epoch 46/100
# 4/4 [==============================] - 0s 8ms/step - loss: 41.5595 - lr: 1.7783e-06
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 40.8562 - lr: 1.9953e-06
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 40.4573 - lr: 2.2387e-06
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 41.5691 - lr: 2.5119e-06
# Epoch 50/100
# 4/4 [==============================] - 0s 8ms/step - loss: 40.1420 - lr: 2.8184e-06
# Epoch 51/100
# 4/4 [==============================] - 0s 9ms/step - loss: 40.1208 - lr: 3.1623e-06
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 38.4343 - lr: 3.5481e-06
# Epoch 53/100
# 4/4 [==============================] - 0s 8ms/step - loss: 38.3814 - lr: 3.9811e-06
# Epoch 54/100
# 4/4 [==============================] - 0s 6ms/step - loss: 37.2849 - lr: 4.4668e-06
# Epoch 55/100
# 4/4 [==============================] - 0s 8ms/step - loss: 40.9635 - lr: 5.0119e-06
# Epoch 56/100
# 4/4 [==============================] - 0s 8ms/step - loss: 38.4634 - lr: 5.6234e-06
# Epoch 57/100
# 4/4 [==============================] - 0s 8ms/step - loss: 40.2524 - lr: 6.3096e-06
# Epoch 58/100
# 4/4 [==============================] - 0s 7ms/step - loss: 37.7675 - lr: 7.0795e-06
# Epoch 59/100
# 4/4 [==============================] - 0s 8ms/step - loss: 38.9459 - lr: 7.9433e-06
# Epoch 60/100
# 4/4 [==============================] - 0s 8ms/step - loss: 39.7232 - lr: 8.9125e-06
# Epoch 61/100
# 4/4 [==============================] - 0s 7ms/step - loss: 41.5194 - lr: 1.0000e-05
# Epoch 62/100
# 4/4 [==============================] - 0s 8ms/step - loss: 38.4245 - lr: 1.1220e-05
# Epoch 63/100
# 4/4 [==============================] - 0s 8ms/step - loss: 43.7997 - lr: 1.2589e-05
# Epoch 64/100
# 4/4 [==============================] - 0s 9ms/step - loss: 49.9485 - lr: 1.4125e-05
# Epoch 65/100
# 4/4 [==============================] - 0s 7ms/step - loss: 47.4635 - lr: 1.5849e-05
# Epoch 66/100
# 4/4 [==============================] - 0s 8ms/step - loss: 47.1177 - lr: 1.7783e-05
# Epoch 67/100
# 4/4 [==============================] - 0s 8ms/step - loss: 48.1200 - lr: 1.9953e-05
# Epoch 68/100
# 4/4 [==============================] - 0s 8ms/step - loss: 47.7032 - lr: 2.2387e-05
# Epoch 69/100
# 4/4 [==============================] - 0s 9ms/step - loss: 55.9021 - lr: 2.5119e-05
# Epoch 70/100
# 4/4 [==============================] - 0s 8ms/step - loss: 54.7050 - lr: 2.8184e-05
# Epoch 71/100
# 4/4 [==============================] - 0s 7ms/step - loss: 56.6046 - lr: 3.1623e-05
# Epoch 72/100
# 4/4 [==============================] - 0s 7ms/step - loss: 60.2441 - lr: 3.5481e-05
# Epoch 73/100
# 4/4 [==============================] - 0s 8ms/step - loss: 96.5004 - lr: 3.9811e-05
# Epoch 74/100
# 4/4 [==============================] - 0s 8ms/step - loss: 71.0478 - lr: 4.4668e-05
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 61.8695 - lr: 5.0119e-05
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 57.6014 - lr: 5.6234e-05
# Epoch 77/100
# 4/4 [==============================] - 0s 7ms/step - loss: 57.3200 - lr: 6.3096e-05
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: 64.0207 - lr: 7.0795e-05
# Epoch 79/100
# 4/4 [==============================] - 0s 7ms/step - loss: 56.8563 - lr: 7.9433e-05
# Epoch 80/100
# 4/4 [==============================] - 0s 7ms/step - loss: 69.5087 - lr: 8.9125e-05
# Epoch 81/100
# 4/4 [==============================] - 0s 9ms/step - loss: 80.8581 - lr: 1.0000e-04
# Epoch 82/100
# 4/4 [==============================] - 0s 8ms/step - loss: 65.3364 - lr: 1.1220e-04
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 79.3924 - lr: 1.2589e-04
# Epoch 84/100
# 4/4 [==============================] - 0s 8ms/step - loss: 70.7979 - lr: 1.4125e-04
# Epoch 85/100
# 4/4 [==============================] - 0s 7ms/step - loss: 76.6845 - lr: 1.5849e-04
# Epoch 86/100
# 4/4 [==============================] - 0s 7ms/step - loss: 70.6264 - lr: 1.7783e-04
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: 63.2177 - lr: 1.9953e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 8ms/step - loss: 119.5262 - lr: 2.2387e-04
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: 73.6275 - lr: 2.5119e-04
# Epoch 90/100
# 4/4 [==============================] - 0s 7ms/step - loss: 83.7755 - lr: 2.8184e-04
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 108.0437 - lr: 3.1623e-04
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 68.8343 - lr: 3.5481e-04
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: 166.1020 - lr: 3.9811e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 7ms/step - loss: 129.2784 - lr: 4.4668e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 6ms/step - loss: 189.5866 - lr: 5.0119e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 7ms/step - loss: 210.1667 - lr: 5.6234e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 8ms/step - loss: 174.0978 - lr: 6.3096e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 9ms/step - loss: 308.3790 - lr: 7.0795e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 330.8203 - lr: 7.9433e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 9ms/step - loss: 258.0568 - lr: 8.9125e-04
# (1e-08, 0.001, 0.0, 100.0)

# %%
# Define a Callback class that stops training once accuracy reaches 99.9%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('mae')<3.0):
            print("\nReached 3 mae, so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# Set the learning rate
learning_rate = 3e-6

# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# Train the model
history = model.fit(train_set,epochs=1000, callbacks=[callbacks])

# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 3s 14ms/step - loss: 120.9026 - mae: 121.4025
# Epoch 2/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 69.6813 - mae: 70.1765
# Epoch 3/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 77.2867 - mae: 77.7867
# Epoch 4/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 77.6512 - mae: 78.1512
# Epoch 5/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 62.0161 - mae: 62.5066
# Epoch 6/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 58.2862 - mae: 58.7854
# Epoch 7/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 56.0789 - mae: 56.5741
# Epoch 8/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 51.2427 - mae: 51.7347
# Epoch 9/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 50.8566 - mae: 51.3503
# Epoch 10/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 50.1886 - mae: 50.6865
# Epoch 11/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 45.9414 - mae: 46.4359
# Epoch 12/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 43.8896 - mae: 44.3828
# Epoch 13/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 44.3164 - mae: 44.8103
# Epoch 14/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 40.3221 - mae: 40.8152
# Epoch 15/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 43.1195 - mae: 43.6175
# Epoch 16/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 39.1786 - mae: 39.6729
# Epoch 17/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 40.1870 - mae: 40.6820
# Epoch 18/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 39.0313 - mae: 39.5281
# Epoch 19/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 38.2598 - mae: 38.7590
# Epoch 20/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 38.0592 - mae: 38.5525
# Epoch 21/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 34.7036 - mae: 35.1933
# Epoch 22/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 35.1485 - mae: 35.6437
# Epoch 23/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 33.7475 - mae: 34.2390
# Epoch 24/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 35.0924 - mae: 35.5886
# Epoch 25/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 30.8761 - mae: 31.3653
# Epoch 26/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 30.9439 - mae: 31.4354
# Epoch 27/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 32.3315 - mae: 32.8213
# Epoch 28/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 29.5792 - mae: 30.0572
# Epoch 29/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 30.1038 - mae: 30.6000
# Epoch 30/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 28.2618 - mae: 28.7519
# Epoch 31/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 27.5408 - mae: 28.0337
# Epoch 32/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 28.2078 - mae: 28.6954
# Epoch 33/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 28.3621 - mae: 28.8590
# Epoch 34/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 28.4537 - mae: 28.9427
# Epoch 35/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 26.8572 - mae: 27.3415
# Epoch 36/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 26.5327 - mae: 27.0227
# Epoch 37/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 24.9844 - mae: 25.4757
# Epoch 38/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 27.1302 - mae: 27.6243
# Epoch 39/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 24.1350 - mae: 24.6154
# Epoch 40/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 22.7909 - mae: 23.2763
# Epoch 41/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.3653 - mae: 25.8553
# Epoch 42/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.5425 - mae: 26.0362
# Epoch 43/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 26.4376 - mae: 26.9360
# Epoch 44/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 27.1731 - mae: 27.6633
# Epoch 45/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 24.0410 - mae: 24.5294
# Epoch 46/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 31.4701 - mae: 31.9661
# Epoch 47/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 29.2159 - mae: 29.7146
# Epoch 48/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 27.7228 - mae: 28.2134
# Epoch 49/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 28.8549 - mae: 29.3499
# Epoch 50/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 24.5147 - mae: 25.0077
# Epoch 51/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 26.9603 - mae: 27.4508
# Epoch 52/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 23.9494 - mae: 24.4402
# Epoch 53/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 23.6443 - mae: 24.1308
# Epoch 54/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 26.6222 - mae: 27.1186
# Epoch 55/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 30.7842 - mae: 31.2828
# Epoch 56/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 25.5139 - mae: 26.0078
# Epoch 57/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.0166 - mae: 23.5087
# Epoch 58/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.5728 - mae: 26.0596
# Epoch 59/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.6219 - mae: 24.1043
# Epoch 60/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 27.1271 - mae: 27.6085
# Epoch 61/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.2308 - mae: 23.7174
# Epoch 62/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.5367 - mae: 26.0203
# Epoch 63/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 27.7332 - mae: 28.2263
# Epoch 64/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.9542 - mae: 23.4372
# Epoch 65/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.6012 - mae: 24.0949
# Epoch 66/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.1424 - mae: 23.6379
# Epoch 67/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 21.7198 - mae: 22.2150
# Epoch 68/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 20.7136 - mae: 21.1876
# Epoch 69/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 20.7086 - mae: 21.1995
# Epoch 70/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.3731 - mae: 22.8651
# Epoch 71/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.4220 - mae: 22.9142
# Epoch 72/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 29.7615 - mae: 30.2531
# Epoch 73/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 27.3253 - mae: 27.8096
# Epoch 74/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.7531 - mae: 23.2506
# Epoch 75/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 27.1254 - mae: 27.6208
# Epoch 76/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 22.1155 - mae: 22.6067
# Epoch 77/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 27.3788 - mae: 27.8708
# Epoch 78/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 29.0457 - mae: 29.5399
# Epoch 79/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.4704 - mae: 25.9593
# Epoch 80/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 28.5564 - mae: 29.0558
# Epoch 81/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 24.4399 - mae: 24.9369
# Epoch 82/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.5210 - mae: 23.0106
# Epoch 83/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 23.7998 - mae: 24.2925
# Epoch 84/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 23.0197 - mae: 23.5158
# Epoch 85/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 23.1533 - mae: 23.6389
# Epoch 86/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 25.5905 - mae: 26.0832
# Epoch 87/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 20.7156 - mae: 21.2104
# Epoch 88/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 21.5113 - mae: 22.0036
# Epoch 89/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 19.6849 - mae: 20.1758
# Epoch 90/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18.7820 - mae: 19.2743
# Epoch 91/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 18.6191 - mae: 19.1097
# Epoch 92/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 33.4527 - mae: 33.9517
# Epoch 93/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 25.7088 - mae: 26.1980
# Epoch 94/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 29.6827 - mae: 30.1768
# Epoch 95/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 24.1729 - mae: 24.6703
# Epoch 96/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 24.6964 - mae: 25.1882
# Epoch 97/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 22.3271 - mae: 22.8207
# Epoch 98/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 23.2264 - mae: 23.7168
# Epoch 99/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 25.4202 - mae: 25.9112
# Epoch 100/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 21.7539 - mae: 22.2347
# Epoch 101/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 21.2607 - mae: 21.7547
# Epoch 102/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 24.9218 - mae: 25.4102
# Epoch 103/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 24.4648 - mae: 24.9648
# Epoch 104/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 20.7290 - mae: 21.2180
# Epoch 105/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.8256 - mae: 20.3141
# Epoch 106/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 21.1149 - mae: 21.6050
# Epoch 107/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.6743 - mae: 24.1558
# Epoch 108/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 21.7312 - mae: 22.2166
# Epoch 109/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.5370 - mae: 18.0174
# Epoch 110/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.7889 - mae: 21.2793
# Epoch 111/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 21.7305 - mae: 22.2262
# Epoch 112/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 19.1261 - mae: 19.6100
# Epoch 113/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 19.5383 - mae: 20.0246
# Epoch 114/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18.0985 - mae: 18.5882
# Epoch 115/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.3212 - mae: 19.8152
# Epoch 116/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.1009 - mae: 19.5919
# Epoch 117/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.3599 - mae: 19.8452
# Epoch 118/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18.5496 - mae: 19.0389
# Epoch 119/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 18.4191 - mae: 18.9146
# Epoch 120/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.2165 - mae: 16.6960
# Epoch 121/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 18.1963 - mae: 18.6800
# Epoch 122/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.4697 - mae: 16.9534
# Epoch 123/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18.8806 - mae: 19.3453
# Epoch 124/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 17.2376 - mae: 17.7132
# Epoch 125/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 23.0286 - mae: 23.5161
# Epoch 126/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.1568 - mae: 16.6302
# Epoch 127/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.7814 - mae: 18.2700
# Epoch 128/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.7817 - mae: 16.2641
# Epoch 129/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.0597 - mae: 17.5377
# Epoch 130/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.9933 - mae: 15.4782
# Epoch 131/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.2065 - mae: 16.6939
# Epoch 132/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.3708 - mae: 15.8559
# Epoch 133/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.3473 - mae: 14.8256
# Epoch 134/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.2661 - mae: 15.7483
# Epoch 135/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.2967 - mae: 16.7854
# Epoch 136/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.8245 - mae: 18.3066
# Epoch 137/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.3519 - mae: 15.8403
# Epoch 138/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 16.6386 - mae: 17.1198
# Epoch 139/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.9375 - mae: 16.4243
# Epoch 140/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.7485 - mae: 16.2212
# Epoch 141/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.0154 - mae: 16.5032
# Epoch 142/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.5816 - mae: 15.0532
# Epoch 143/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.1938 - mae: 14.6710
# Epoch 144/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.9435 - mae: 16.4200
# Epoch 145/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.4913 - mae: 14.9735
# Epoch 146/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 16.2581 - mae: 16.7358
# Epoch 147/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 14.4476 - mae: 14.9397
# Epoch 148/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.8733 - mae: 16.3673
# Epoch 149/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.1960 - mae: 15.6788
# Epoch 150/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 14.3515 - mae: 14.8363
# Epoch 151/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.4929 - mae: 14.9856
# Epoch 152/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.8231 - mae: 16.3174
# Epoch 153/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 15.0264 - mae: 15.5193
# Epoch 154/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.1078 - mae: 16.5990
# Epoch 155/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 18.7859 - mae: 19.2734
# Epoch 156/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.3894 - mae: 17.8793
# Epoch 157/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.9701 - mae: 21.4700
# Epoch 158/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.2163 - mae: 16.7009
# Epoch 159/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.9875 - mae: 15.4613
# Epoch 160/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.0375 - mae: 17.5103
# Epoch 161/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.0773 - mae: 16.5614
# Epoch 162/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.0822 - mae: 14.5546
# Epoch 163/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.6848 - mae: 18.1624
# Epoch 164/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.2143 - mae: 15.6983
# Epoch 165/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.4374 - mae: 19.9145
# Epoch 166/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 19.9137 - mae: 20.4025
# Epoch 167/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.6299 - mae: 15.1180
# Epoch 168/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.0673 - mae: 14.5444
# Epoch 169/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.6176 - mae: 15.1113
# Epoch 170/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.5889 - mae: 15.0594
# Epoch 171/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.4188 - mae: 14.9037
# Epoch 172/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.9275 - mae: 16.4242
# Epoch 173/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.3299 - mae: 15.8209
# Epoch 174/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.6779 - mae: 14.1531
# Epoch 175/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 17.1711 - mae: 17.6568
# Epoch 176/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.6705 - mae: 21.1640
# Epoch 177/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.1797 - mae: 15.6624
# Epoch 178/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 13.8694 - mae: 14.3613
# Epoch 179/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.3791 - mae: 13.8691
# Epoch 180/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.9225 - mae: 13.4104
# Epoch 181/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.8791 - mae: 13.3602
# Epoch 182/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.3145 - mae: 13.7972
# Epoch 183/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.6068 - mae: 13.0848
# Epoch 184/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.5661 - mae: 13.0439
# Epoch 185/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1707 - mae: 12.6507
# Epoch 186/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 13.5754 - mae: 14.0649
# Epoch 187/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.2486 - mae: 12.7251
# Epoch 188/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.4003 - mae: 12.8814
# Epoch 189/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 11.9556 - mae: 12.4378
# Epoch 190/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.6433 - mae: 14.1285
# Epoch 191/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.1802 - mae: 13.6729
# Epoch 192/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.4998 - mae: 12.9822
# Epoch 193/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.5552 - mae: 13.0375
# Epoch 194/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9875 - mae: 12.4717
# Epoch 195/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.0584 - mae: 12.5383
# Epoch 196/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.8277 - mae: 11.2951
# Epoch 197/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.9878 - mae: 11.4563
# Epoch 198/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.9425 - mae: 11.4101
# Epoch 199/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.2573 - mae: 10.7202
# Epoch 200/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.5805 - mae: 12.0486
# Epoch 201/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.2728 - mae: 13.7566
# Epoch 202/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.3756 - mae: 12.8567
# Epoch 203/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1527 - mae: 12.6228
# Epoch 204/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.3596 - mae: 15.8489
# Epoch 205/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.2644 - mae: 13.7525
# Epoch 206/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.6972 - mae: 15.1919
# Epoch 207/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.8376 - mae: 13.3235
# Epoch 208/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.1792 - mae: 13.6694
# Epoch 209/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 18.3698 - mae: 18.8640
# Epoch 210/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.4733 - mae: 16.9606
# Epoch 211/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.6505 - mae: 14.1239
# Epoch 212/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.5151 - mae: 12.9925
# Epoch 213/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 15.1466 - mae: 15.6447
# Epoch 214/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9854 - mae: 12.4696
# Epoch 215/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.9049 - mae: 12.3612
# Epoch 216/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 11.5794 - mae: 12.0544
# Epoch 217/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.3798 - mae: 12.8528
# Epoch 218/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.6263 - mae: 13.1109
# Epoch 219/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.8750 - mae: 14.3600
# Epoch 220/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.3676 - mae: 12.8586
# Epoch 221/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.1201 - mae: 20.6184
# Epoch 222/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.8738 - mae: 18.3672
# Epoch 223/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.6239 - mae: 16.1084
# Epoch 224/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.9121 - mae: 15.4065
# Epoch 225/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 14.9498 - mae: 15.4437
# Epoch 226/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.0750 - mae: 17.5449
# Epoch 227/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.7711 - mae: 18.2424
# Epoch 228/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 15.3760 - mae: 15.8266
# Epoch 229/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 12.1616 - mae: 12.6308
# Epoch 230/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.6400 - mae: 13.1058
# Epoch 231/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.6740 - mae: 13.1648
# Epoch 232/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.0080 - mae: 15.4958
# Epoch 233/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.7387 - mae: 13.2221
# Epoch 234/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.3040 - mae: 13.7953
# Epoch 235/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.9216 - mae: 13.4132
# Epoch 236/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.5013 - mae: 13.9903
# Epoch 237/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.8566 - mae: 14.3379
# Epoch 238/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.0505 - mae: 13.5304
# Epoch 239/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.2597 - mae: 12.7312
# Epoch 240/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1326 - mae: 12.5968
# Epoch 241/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.4637 - mae: 10.9332
# Epoch 242/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.7972 - mae: 20.2884
# Epoch 243/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.6768 - mae: 15.1729
# Epoch 244/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.0547 - mae: 14.5257
# Epoch 245/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.4821 - mae: 14.9653
# Epoch 246/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.6807 - mae: 13.1605
# Epoch 247/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 11.1491 - mae: 11.6364
# Epoch 248/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.3064 - mae: 11.7665
# Epoch 249/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.0385 - mae: 12.5203
# Epoch 250/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.6209 - mae: 16.1152
# Epoch 251/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.7069 - mae: 17.1994
# Epoch 252/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.1353 - mae: 13.6177
# Epoch 253/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 10.7600 - mae: 11.2439
# Epoch 254/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.2310 - mae: 13.7216
# Epoch 255/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.4968 - mae: 12.9808
# Epoch 256/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.2683 - mae: 13.7546
# Epoch 257/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.1933 - mae: 15.6777
# Epoch 258/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.2612 - mae: 13.7491
# Epoch 259/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.6179 - mae: 13.1075
# Epoch 260/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.8836 - mae: 12.3682
# Epoch 261/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 10.6676 - mae: 11.1482
# Epoch 262/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 11.5599 - mae: 12.0445
# Epoch 263/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.4759 - mae: 15.9629
# Epoch 264/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.0494 - mae: 13.5388
# Epoch 265/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.2397 - mae: 12.7170
# Epoch 266/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.5722 - mae: 12.0596
# Epoch 267/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 12.5460 - mae: 13.0109
# Epoch 268/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.5331 - mae: 12.0184
# Epoch 269/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.5305 - mae: 15.0025
# Epoch 270/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 18.3041 - mae: 18.7879
# Epoch 271/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.9585 - mae: 12.4352
# Epoch 272/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.1861 - mae: 11.6667
# Epoch 273/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.8279 - mae: 12.3101
# Epoch 274/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.8843 - mae: 18.3586
# Epoch 275/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.6349 - mae: 20.1234
# Epoch 276/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.5638 - mae: 13.0324
# Epoch 277/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.2177 - mae: 13.6939
# Epoch 278/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.4918 - mae: 11.9762
# Epoch 279/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.9434 - mae: 15.4082
# Epoch 280/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.3469 - mae: 11.8313
# Epoch 281/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.8391 - mae: 13.3258
# Epoch 282/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.8402 - mae: 10.3195
# Epoch 283/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.3112 - mae: 10.7968
# Epoch 284/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.3571 - mae: 12.8393
# Epoch 285/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 10.2980 - mae: 10.7830
# Epoch 286/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 10.5724 - mae: 11.0531
# Epoch 287/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.1218 - mae: 12.6134
# Epoch 288/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.5342 - mae: 11.0151
# Epoch 289/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.8223 - mae: 10.3102
# Epoch 290/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.2868 - mae: 13.7673
# Epoch 291/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.9852 - mae: 13.4645
# Epoch 292/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.1109 - mae: 16.5852
# Epoch 293/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.8129 - mae: 13.2995
# Epoch 294/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.4501 - mae: 10.9328
# Epoch 295/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.5985 - mae: 11.0895
# Epoch 296/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.7765 - mae: 12.2583
# Epoch 297/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.3136 - mae: 13.7996
# Epoch 298/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.2523 - mae: 11.7461
# Epoch 299/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.2847 - mae: 15.7653
# Epoch 300/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.8360 - mae: 11.3144
# Epoch 301/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.4802 - mae: 10.9601
# Epoch 302/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.5048 - mae: 10.9697
# Epoch 303/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 9.8108 - mae: 10.2949
# Epoch 304/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.7487 - mae: 12.2343
# Epoch 305/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.1494 - mae: 11.6341
# Epoch 306/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.3638 - mae: 12.8538
# Epoch 307/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.4904 - mae: 11.9772
# Epoch 308/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.2670 - mae: 11.7495
# Epoch 309/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.7767 - mae: 13.2665
# Epoch 310/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.4614 - mae: 11.9354
# Epoch 311/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.3112 - mae: 12.7977
# Epoch 312/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.9360 - mae: 13.4302
# Epoch 313/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 15.4139 - mae: 15.9005
# Epoch 314/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9099 - mae: 12.3912
# Epoch 315/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.2469 - mae: 9.7248
# Epoch 316/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.0816 - mae: 12.5785
# Epoch 317/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.1638 - mae: 14.6638
# Epoch 318/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 17.6059 - mae: 18.0971
# Epoch 319/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 25.0186 - mae: 25.5142
# Epoch 320/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.1121 - mae: 19.6121
# Epoch 321/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 14.9690 - mae: 15.4599
# Epoch 322/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.5328 - mae: 15.0189
# Epoch 323/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.0393 - mae: 14.5290
# Epoch 324/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.2970 - mae: 13.7699
# Epoch 325/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.9090 - mae: 12.3999
# Epoch 326/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.4111 - mae: 12.8892
# Epoch 327/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.0399 - mae: 12.4996
# Epoch 328/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.2443 - mae: 15.7243
# Epoch 329/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.1770 - mae: 13.6569
# Epoch 330/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.2887 - mae: 12.7641
# Epoch 331/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.7347 - mae: 10.2213
# Epoch 332/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.1305 - mae: 12.5961
# Epoch 333/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.8446 - mae: 14.3408
# Epoch 334/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.7157 - mae: 14.2034
# Epoch 335/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.2537 - mae: 11.7296
# Epoch 336/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.2793 - mae: 11.7570
# Epoch 337/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.3009 - mae: 14.7912
# Epoch 338/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.9308 - mae: 14.4072
# Epoch 339/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.3780 - mae: 11.8747
# Epoch 340/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.7834 - mae: 12.2635
# Epoch 341/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.6740 - mae: 9.1421
# Epoch 342/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.9015 - mae: 12.3951
# Epoch 343/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.6672 - mae: 11.1517
# Epoch 344/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.6903 - mae: 9.1777
# Epoch 345/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 10.2296 - mae: 10.7175
# Epoch 346/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9832 - mae: 12.4690
# Epoch 347/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.1835 - mae: 9.6625
# Epoch 348/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.8858 - mae: 10.3813
# Epoch 349/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.3276 - mae: 9.8171
# Epoch 350/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.4123 - mae: 10.8958
# Epoch 351/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.1825 - mae: 12.6663
# Epoch 352/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.0180 - mae: 11.5024
# Epoch 353/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9385 - mae: 12.4291
# Epoch 354/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.2449 - mae: 9.7385
# Epoch 355/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.4872 - mae: 9.9826
# Epoch 356/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.4452 - mae: 9.9336
# Epoch 357/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 8.5410 - mae: 9.0124
# Epoch 358/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.7642 - mae: 10.2355
# Epoch 359/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.8359 - mae: 11.3255
# Epoch 360/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 8.8498 - mae: 9.3348
# Epoch 361/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.3577 - mae: 9.8415
# Epoch 362/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.6299 - mae: 9.1123
# Epoch 363/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.7176 - mae: 8.2030
# Epoch 364/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.9297 - mae: 8.4157
# Epoch 365/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.8030 - mae: 10.2922
# Epoch 366/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.6619 - mae: 10.1459
# Epoch 367/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.2935 - mae: 8.7654
# Epoch 368/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.2016 - mae: 10.6813
# Epoch 369/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.1746 - mae: 10.6520
# Epoch 370/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.5851 - mae: 11.0665
# Epoch 371/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.6705 - mae: 10.1343
# Epoch 372/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.9439 - mae: 10.4171
# Epoch 373/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.3438 - mae: 9.8195
# Epoch 374/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.3717 - mae: 11.8430
# Epoch 375/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.0908 - mae: 10.5526
# Epoch 376/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.9363 - mae: 11.4168
# Epoch 377/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.3448 - mae: 10.8116
# Epoch 378/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.3902 - mae: 10.8706
# Epoch 379/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.6220 - mae: 11.0983
# Epoch 380/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.0719 - mae: 10.5483
# Epoch 381/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.5842 - mae: 12.0813
# Epoch 382/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.0441 - mae: 12.5293
# Epoch 383/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.4678 - mae: 10.9510
# Epoch 384/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.1377 - mae: 11.6129
# Epoch 385/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.9141 - mae: 13.3841
# Epoch 386/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.8510 - mae: 21.3327
# Epoch 387/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.9269 - mae: 15.4110
# Epoch 388/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.6053 - mae: 14.0780
# Epoch 389/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1483 - mae: 12.6194
# Epoch 390/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.8057 - mae: 11.2900
# Epoch 391/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.0652 - mae: 10.5475
# Epoch 392/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.4691 - mae: 9.9387
# Epoch 393/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.9229 - mae: 12.4057
# Epoch 394/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.0188 - mae: 11.4973
# Epoch 395/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.1403 - mae: 16.6191
# Epoch 396/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.4525 - mae: 11.9261
# Epoch 397/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.4450 - mae: 11.9199
# Epoch 398/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.0501 - mae: 8.5303
# Epoch 399/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.4391 - mae: 9.9047
# Epoch 400/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.9490 - mae: 11.4291
# Epoch 401/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.8093 - mae: 11.2823
# Epoch 402/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.9281 - mae: 10.4117
# Epoch 403/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 10.1906 - mae: 10.6606
# Epoch 404/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1341 - mae: 12.6204
# Epoch 405/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.7554 - mae: 17.2463
# Epoch 406/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 20.7189 - mae: 21.2157
# Epoch 407/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.3474 - mae: 14.8327
# Epoch 408/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.4683 - mae: 11.9508
# Epoch 409/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 15.1849 - mae: 15.6747
# Epoch 410/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 20.9057 - mae: 21.3992
# Epoch 411/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 20.2015 - mae: 20.6815
# Epoch 412/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.3609 - mae: 16.8508
# Epoch 413/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.3405 - mae: 13.8312
# Epoch 414/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 16.0123 - mae: 16.4816
# Epoch 415/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 17.7464 - mae: 18.2244
# Epoch 416/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.0723 - mae: 16.5550
# Epoch 417/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1033 - mae: 12.5892
# Epoch 418/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 19.7256 - mae: 20.2124
# Epoch 419/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 19.1794 - mae: 19.6688
# Epoch 420/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 16.8298 - mae: 17.3136
# Epoch 421/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.3594 - mae: 13.8350
# Epoch 422/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.1613 - mae: 12.6372
# Epoch 423/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 14.9232 - mae: 15.4072
# Epoch 424/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.1382 - mae: 11.6186
# Epoch 425/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.8575 - mae: 14.3483
# Epoch 426/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.2353 - mae: 12.7223
# Epoch 427/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.6828 - mae: 12.1789
# Epoch 428/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.8456 - mae: 10.3307
# Epoch 429/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.7688 - mae: 13.2570
# Epoch 430/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 13.2213 - mae: 13.7111
# Epoch 431/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.7194 - mae: 15.2092
# Epoch 432/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 12.7427 - mae: 13.2396
# Epoch 433/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 10.9078 - mae: 11.3986
# Epoch 434/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.5674 - mae: 11.0560
# Epoch 435/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.5906 - mae: 10.0828
# Epoch 436/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.1120 - mae: 8.5856
# Epoch 437/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 7.8814 - mae: 8.3606
# Epoch 438/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 11.3102 - mae: 11.7967
# Epoch 439/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.8079 - mae: 15.2959
# Epoch 440/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 13.4520 - mae: 13.9358
# Epoch 441/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 14.2036 - mae: 14.6961
# Epoch 442/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 14.4417 - mae: 14.9190
# Epoch 443/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.2386 - mae: 10.7197
# Epoch 444/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.0003 - mae: 10.4902
# Epoch 445/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.3888 - mae: 9.8667
# Epoch 446/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.7468 - mae: 11.2281
# Epoch 447/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 12.8678 - mae: 13.3642
# Epoch 448/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.6615 - mae: 9.1419
# Epoch 449/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.8728 - mae: 9.3602
# Epoch 450/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.0536 - mae: 11.5399
# Epoch 451/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.0858 - mae: 11.5732
# Epoch 452/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.3752 - mae: 8.8629
# Epoch 453/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.6925 - mae: 9.1658
# Epoch 454/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.9298 - mae: 7.4033
# Epoch 455/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 7.7731 - mae: 8.2451
# Epoch 456/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.4421 - mae: 7.9127
# Epoch 457/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 14.1205 - mae: 14.5928
# Epoch 458/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 11.6887 - mae: 12.1826
# Epoch 459/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.1898 - mae: 8.6706
# Epoch 460/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 12.2640 - mae: 12.7433
# Epoch 461/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 15.3484 - mae: 15.8236
# Epoch 462/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.4835 - mae: 11.9547
# Epoch 463/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.3738 - mae: 10.8386
# Epoch 464/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.9586 - mae: 11.4442
# Epoch 465/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.6789 - mae: 10.1665
# Epoch 466/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 8.1110 - mae: 8.5808
# Epoch 467/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.5794 - mae: 10.0589
# Epoch 468/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.9856 - mae: 8.4727
# Epoch 469/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.7925 - mae: 8.2795
# Epoch 470/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.5767 - mae: 8.0523
# Epoch 471/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 7.9377 - mae: 8.4102
# Epoch 472/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 10.1545 - mae: 10.6390
# Epoch 473/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.2830 - mae: 8.7475
# Epoch 474/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.7360 - mae: 7.2186
# Epoch 475/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.1365 - mae: 7.6076
# Epoch 476/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.7937 - mae: 8.2666
# Epoch 477/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.0389 - mae: 8.5061
# Epoch 478/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8027 - mae: 6.2856
# Epoch 479/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.4236 - mae: 5.8837
# Epoch 480/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.3155 - mae: 6.7961
# Epoch 481/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.4578 - mae: 8.9242
# Epoch 482/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 10.5683 - mae: 11.0528
# Epoch 483/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.2960 - mae: 8.7692
# Epoch 484/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.1594 - mae: 7.6289
# Epoch 485/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.0959 - mae: 8.5792
# Epoch 486/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.2191 - mae: 8.6946
# Epoch 487/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.3965 - mae: 7.8689
# Epoch 488/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.9600 - mae: 8.4310
# Epoch 489/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 11.1107 - mae: 11.5938
# Epoch 490/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.2483 - mae: 11.7319
# Epoch 491/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 11.2145 - mae: 11.7077
# Epoch 492/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.9515 - mae: 8.4363
# Epoch 493/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.6380 - mae: 7.1188
# Epoch 494/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2373 - mae: 6.6811
# Epoch 495/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 7.3711 - mae: 7.8343
# Epoch 496/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2322 - mae: 6.6990
# Epoch 497/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.4316 - mae: 6.9093
# Epoch 498/1000
# ...
# Epoch 763/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.0210 - mae: 10.5016
# Epoch 764/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.9759 - mae: 11.4544
# Epoch 765/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.3225 - mae: 8.7998
# Epoch 766/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.6060 - mae: 7.0873
# Epoch 767/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.4685 - mae: 7.9522
# Epoch 768/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.7122 - mae: 6.1814
# Epoch 769/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.5295 - mae: 6.0188
# Epoch 770/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.1756 - mae: 6.6689
# Epoch 771/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.4847 - mae: 7.9737
# Epoch 772/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.3735 - mae: 6.8444
# Epoch 773/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.4208 - mae: 5.8936
# Epoch 774/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.5781 - mae: 6.0609
# Epoch 775/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8942 - mae: 6.3594
# Epoch 776/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.1389 - mae: 5.6176
# Epoch 777/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.7201 - mae: 7.2001
# Epoch 778/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.2727 - mae: 10.7542
# Epoch 779/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.5312 - mae: 8.0149
# Epoch 780/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.3350 - mae: 9.8094
# Epoch 781/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.6315 - mae: 7.1051
# Epoch 782/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.4876 - mae: 5.9361
# Epoch 783/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.7848 - mae: 6.2629
# Epoch 784/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.7703 - mae: 5.2430
# Epoch 785/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.7157 - mae: 6.2025
# Epoch 786/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.2382 - mae: 5.6902
# Epoch 787/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.3447 - mae: 4.8153
# Epoch 788/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.5775 - mae: 5.0263
# Epoch 789/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.3957 - mae: 5.8480
# Epoch 790/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.3571 - mae: 5.8438
# Epoch 791/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.9414 - mae: 8.4089
# Epoch 792/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.5875 - mae: 5.0307
# Epoch 793/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.7709 - mae: 5.2418
# Epoch 794/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.3143 - mae: 5.7956
# Epoch 795/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.4981 - mae: 4.9682
# Epoch 796/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 6.8397 - mae: 7.3179
# Epoch 797/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.1825 - mae: 5.6455
# Epoch 798/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 5.3130 - mae: 5.7945
# Epoch 799/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.4945 - mae: 6.9639
# Epoch 800/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.1684 - mae: 7.6446
# Epoch 801/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.9441 - mae: 9.4285
# Epoch 802/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.9372 - mae: 5.4064
# Epoch 803/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.8144 - mae: 5.2828
# Epoch 804/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.7699 - mae: 6.2469
# Epoch 805/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.1265 - mae: 6.6047
# Epoch 806/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.5361 - mae: 7.0194
# Epoch 807/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.5712 - mae: 5.0441
# Epoch 808/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.5050 - mae: 5.9735
# Epoch 809/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.4383 - mae: 4.8926
# Epoch 810/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.6418 - mae: 7.1122
# Epoch 811/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.3257 - mae: 7.8098
# Epoch 812/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.1977 - mae: 9.6944
# Epoch 813/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.7258 - mae: 9.2111
# Epoch 814/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.5721 - mae: 10.0431
# Epoch 815/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.2061 - mae: 7.6904
# Epoch 816/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.4634 - mae: 8.9438
# Epoch 817/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 10.2295 - mae: 10.6900
# Epoch 818/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.7958 - mae: 10.2692
# Epoch 819/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.6905 - mae: 8.1723
# Epoch 820/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.1873 - mae: 7.6582
# Epoch 821/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 5.6560 - mae: 6.1281
# Epoch 822/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.4085 - mae: 5.8734
# Epoch 823/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.6730 - mae: 5.1312
# Epoch 824/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.9490 - mae: 5.4168
# Epoch 825/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 4.3491 - mae: 4.7809
# Epoch 826/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3132 - mae: 3.7637
# Epoch 827/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.7459 - mae: 4.2128
# Epoch 828/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 4.7991 - mae: 5.2700
# Epoch 829/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.9260 - mae: 4.3908
# Epoch 830/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2646 - mae: 6.7411
# Epoch 831/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.4059 - mae: 7.8834
# Epoch 832/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.8960 - mae: 6.3761
# Epoch 833/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.4673 - mae: 6.9531
# Epoch 834/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.4696 - mae: 5.9558
# Epoch 835/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.4330 - mae: 6.9241
# Epoch 836/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.2903 - mae: 7.7777
# Epoch 837/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.7341 - mae: 9.2309
# Epoch 838/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 13.0712 - mae: 13.5652
# Epoch 839/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 8.9693 - mae: 9.4472
# Epoch 840/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.0733 - mae: 8.5190
# Epoch 841/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.9032 - mae: 7.3839
# Epoch 842/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.4262 - mae: 5.8860
# Epoch 843/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.9785 - mae: 6.4680
# Epoch 844/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.9244 - mae: 5.4075
# Epoch 845/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.7691 - mae: 4.2304
# Epoch 846/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.6836 - mae: 4.1536
# Epoch 847/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2779 - mae: 3.7565
# Epoch 848/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.4303 - mae: 4.9175
# Epoch 849/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 7.0926 - mae: 7.5855
# Epoch 850/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 5.6677 - mae: 6.1474
# Epoch 851/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.4950 - mae: 4.9735
# Epoch 852/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.7520 - mae: 5.2249
# Epoch 853/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.2871 - mae: 5.7608
# Epoch 854/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.4267 - mae: 4.8963
# Epoch 855/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.0262 - mae: 5.4925
# Epoch 856/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.3170 - mae: 4.7880
# Epoch 857/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 3.8653 - mae: 4.3464
# Epoch 858/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 3.0682 - mae: 3.5421
# Epoch 859/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.3517 - mae: 4.8194
# Epoch 860/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.2021 - mae: 8.6774
# Epoch 861/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.8013 - mae: 7.2676
# Epoch 862/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.6308 - mae: 9.1231
# Epoch 863/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.9048 - mae: 5.3891
# Epoch 864/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2001 - mae: 6.6908
# Epoch 865/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.6515 - mae: 5.1282
# Epoch 866/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.4992 - mae: 4.9778
# Epoch 867/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.0466 - mae: 4.4905
# Epoch 868/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.8823 - mae: 4.3456
# Epoch 869/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2653 - mae: 6.7394
# Epoch 870/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.4159 - mae: 6.9002
# Epoch 871/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.5506 - mae: 7.0039
# Epoch 872/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.9785 - mae: 8.4403
# Epoch 873/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 7.7823 - mae: 8.2457
# Epoch 874/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.5738 - mae: 8.0534
# Epoch 875/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.8882 - mae: 7.3655
# Epoch 876/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.1433 - mae: 5.6159
# Epoch 877/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 7.6827 - mae: 8.1607
# Epoch 878/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 5.8863 - mae: 6.3512
# Epoch 879/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 7.2017 - mae: 7.6946
# Epoch 880/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.6341 - mae: 7.1051
# Epoch 881/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 10.7223 - mae: 11.1817
# Epoch 882/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 11.9007 - mae: 12.3652
# Epoch 883/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 9.4927 - mae: 9.9684
# Epoch 884/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.0685 - mae: 6.5395
# Epoch 885/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 8.9536 - mae: 9.4377
# Epoch 886/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.7629 - mae: 7.2423
# Epoch 887/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.9318 - mae: 6.4023
# Epoch 888/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 8.1958 - mae: 8.6778
# Epoch 889/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.8304 - mae: 7.3014
# Epoch 890/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.1177 - mae: 7.6139
# Epoch 891/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.8964 - mae: 7.3629
# Epoch 892/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.6365 - mae: 6.0998
# Epoch 893/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.3499 - mae: 5.8056
# Epoch 894/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.3271 - mae: 7.8071
# Epoch 895/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 9.3477 - mae: 9.8318
# Epoch 896/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2565 - mae: 6.7332
# Epoch 897/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.8322 - mae: 7.3008
# Epoch 898/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.4880 - mae: 5.9586
# Epoch 899/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.4583 - mae: 5.9424
# Epoch 900/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 7.9166 - mae: 8.4155
# Epoch 901/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.0456 - mae: 5.5002
# Epoch 902/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 5.8522 - mae: 6.3316
# Epoch 903/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.8912 - mae: 5.3591
# Epoch 904/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.5277 - mae: 3.9927
# Epoch 905/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.4974 - mae: 5.9849
# Epoch 906/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 6.1632 - mae: 6.6428
# Epoch 907/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.3311 - mae: 4.7961
# Epoch 908/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.3945 - mae: 4.8665
# Epoch 909/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 5.3389 - mae: 5.7977
# Epoch 910/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.8592 - mae: 4.3335
# Epoch 911/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.6065 - mae: 5.0704
# Epoch 912/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.7639 - mae: 5.2433
# Epoch 913/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.8629 - mae: 4.3334
# Epoch 914/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.9776 - mae: 4.4281
# Epoch 915/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.5838 - mae: 5.0568
# Epoch 916/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.6139 - mae: 4.0733
# Epoch 917/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.0309 - mae: 4.5038
# Epoch 918/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 4.3089 - mae: 4.7715
# Epoch 919/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 6.1348 - mae: 6.6039
# Epoch 920/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.0721 - mae: 5.5421
# Epoch 921/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.1493 - mae: 4.5974
# Epoch 922/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.1704 - mae: 3.6251
# Epoch 923/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.6315 - mae: 4.1139
# Epoch 924/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2134 - mae: 3.6816
# Epoch 925/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3068 - mae: 3.7617
# Epoch 926/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3912 - mae: 3.8566
# Epoch 927/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 2.8727 - mae: 3.3177
# Epoch 928/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 2.5602 - mae: 3.0223
# Epoch 929/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 2.0505 - mae: 2.4959
# Reached 3 mae, so cancelling training!
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5373 - mae: 2.9845

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))

    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)

    # Get predictions on the entire dataset
    forecast = model.predict(dataset)

    return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results
plot_series(time_valid, (x_valid, results))
# Out:
# 1/1 [==============================] - 1s 686ms/step

# %%
results
# Out:
# array([[ 33.73286 , 206.03233 ],
#        [ 33.61407 ,  27.444899],
#        [ 29.508139,  23.081198],
#        [ 30.765558, 114.670906],
#        [ 27.1788  , 186.3287  ],
#        [ 30.210806, 240.76384 ]], dtype=float32)

# %%
# Compute the MAE
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# [ 86.26974     7.3044844  59.43533   421.37177    89.306244   29.856518 ]
